# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaaSoudy/python-projects/blob/main/DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {

  "Name": ["Ali","Alaa"],
  "Age" :  [ 25, 23],
  "Gpa" : [3.5 ,3.8]
}
dt=pd.DataFrame(data)
dt

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=dt)

# %%
s=pd.Series([1,2,3,4])
s

# %%
grades=pd.Series([90,85,86,97], index=["A" , "B" ,"C ","D"])
grades

# %%
df=pd.read_csv("/content/drive/MyDrive/DA/student_performance_data - student_performance_data.csv")
print(f" Data: {df.head(5)}, \n\nShape: {df.shape}")

# %%
df.info()
print(df.dtypes)
print(df.columns)
df.describe()

# %%
df.boxplot()

# %%
m_s=df["StudentID"].mean()
print(m_s)

# %%
print(df.iloc[0:4, 0:8],"\n")
print("\n",df.loc[0:4 ,'StudentID': 'Age'])

# %%
df.iloc[0:5 , 0:3]

# %%
def gender(x):
  if x=='Male':
    x=1
    return x
  else:
    x=0
    return x

# %%
df["gender_idx"]=df["Gender"].apply(lambda x:gender(x))
df.head(10)

# %%
df['Age'].value_counts(normalize=True)

# %%
import matplotlib.pyplot as plt

major_counts = df['Major'].value_counts()

plt.figure(figsize=(7, 4))
plt.bar(major_counts.index, major_counts.values)
plt.title("Student Count by Major")
plt.xlabel("Major")
plt.ylabel("Number of Students")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
