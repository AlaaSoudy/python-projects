# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaaSoudy/python-projects/blob/main/DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {

  "Name": ["Ali","Alaa"],
  "Age" :  [ 25, 23],
  "Gpa" : [3.5 ,3.8]
}
df=pd.DataFrame(data)
df

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)

# %%
s=pd.Series([1,2,3,4])
s

# %%
grades=pd.Series([90,85,86,97], index=["A" , "B" ,"C ","D"])
grades

# %%
DT=pd.read_csv("/content/drive/MyDrive/DA/student_performance_data - student_performance_data.csv")
print(f" Data: {DT.head(5)}, \n\nShape: {DT.shape}")

# %%
df.info()
